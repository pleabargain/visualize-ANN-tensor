# %% [markdown]
# On ubuntu 16.04 LTS I needed
#
# sudo apt-get install graphviz
#
# to get this to work
#
# and go to kaggle.com and get the pima data.

# %% [markdown]
# # explanation of pima data set
#
# # 1. Number of times pregnant
# # 2. Plasma glucose concentration a 2 hours in an oral glucose tolerance test
# # 3. Diastolic blood pressure (mm Hg)
# # 4. Triceps skin fold thickness (mm)
# # 5. 2-Hour serum insulin (mu U/ml)
# # 6. Body mass index (weight in kg/(height in m)^2)
# # 7. Diabetes pedigree function
# # 8. Age (years)
# # 9. Class variable (0 or 1)

# %%
# !pip3 install --user keras
# !pip3 install --user ann_visualizer
# !pip3 install --user graphviz
# Out:
# ...
# ipywidgets 7.1.2 has requirement widgetsnbextension~=3.1.0, but you'll have widgetsnbextension 3.2.1 which is incompatible.
# ...
# ipywidgets 7.1.2 has requirement widgetsnbextension~=3.1.0, but you'll have widgetsnbextension 3.2.1 which is incompatible.
# ...
# ipywidgets 7.1.2 has requirement widgetsnbextension~=3.1.0, but you'll have widgetsnbextension 3.2.1 which is incompatible.

# %%
# Create your first MLP in Keras
from keras.models import Sequential
from keras.layers import Dense
import numpy
# fix random seed for reproducibility
numpy.random.seed(7)
# load pima indians dataset
dataset = numpy.loadtxt("pima-indians-diabetes.data.csv", delimiter=",")
# split into input (X) and output (Y) variables
X = dataset[:,0:8]
Y = dataset[:,8]
# create model
model = Sequential()
model.add(Dense(12, input_dim=8, activation='relu'))
model.add(Dense(8, activation='relu'))
model.add(Dense(1, activation='sigmoid'))
# Compile model
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
# Fit the model
model.fit(X, Y, epochs=150, batch_size=10)
# evaluate the model
scores = model.evaluate(X, Y)
print("\n%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))
# Out:
# Epoch 1/150
# 768/768 [==============================] - 0s 351us/step - loss: 3.7098 - acc: 0.5977
# Epoch 2/150
# 768/768 [==============================] - 0s 107us/step - loss: 0.9373 - acc: 0.5924
# Epoch 3/150
# 768/768 [==============================] - 0s 108us/step - loss: 0.7478 - acc: 0.6445
# Epoch 4/150
# 768/768 [==============================] - 0s 110us/step - loss: 0.7123 - acc: 0.6523
# Epoch 5/150
# 768/768 [==============================] - 0s 113us/step - loss: 0.6825 - acc: 0.6758
# Epoch 6/150
# 768/768 [==============================] - 0s 111us/step - loss: 0.6516 - acc: 0.6810
# Epoch 7/150
# 768/768 [==============================] - 0s 106us/step - loss: 0.6497 - acc: 0.6719
# Epoch 8/150
# 768/768 [==============================] - 0s 110us/step - loss: 0.6362 - acc: 0.6914
# Epoch 9/150
# 768/768 [==============================] - 0s 114us/step - loss: 0.6245 - acc: 0.6914
# Epoch 10/150
# ...

# %% [markdown]
# load the visualizer

# %%
from ann_visualizer.visualize import ann_viz;

ann_viz(model, title="My first neural network")

# %% [markdown]
# for ubuntu 16.04 LTS I did
#
# sudo apt-get install graphviz
#
#
# and it worked. A pdf was displayed after running the last bit of code.
